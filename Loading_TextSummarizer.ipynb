# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/TextSummarizer
# Out:
# /content/drive/MyDrive/TextSummarizer

# %%
ls
# Out:
# Loading_TextSummarizer.ipynb  Summarization_Using_Transformers.ipynb
# pegasus-samsum-model/         tokenizer/

# %%
pwd
# Out:
# '/content/drive/MyDrive/TextSummarizer'
